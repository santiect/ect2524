# %% [markdown]
# # Avaliação Parcial 2 - Unidade 1 (30%)
#
# 1. Atividade em equipes de até 3 pessoas;
# 2. Completar o Notebook, baixar arquivo .ipynb e enviar via SIGAA ao professor respeitando pra limite da respectiva atividade.

# %% [markdown]
# ## Equipe
#
# * Membro #1: *nome* -  *email*
# * Membro #2: *nome* -  *email*
# * Membro #3: *nome* -  *email*

# %% [markdown]
# ## Objetivo
#
# Implementar a heurística do $k$-means para resolver Problema de Agrupamento pela Soma dos Mínimos Quadrados (MSSC).

# %% [markdown]
# ## Tarefa

# %% [markdown]
# ## Etapa 1
#
# Forneça uma função que recebe como argumento um conjunto de pontos $X$ no espaço Euclidiano $\mathbb{R}^q$, bem como a quantidade  $k$ de clusters a serem formados e um valor para alimentar a semente do gerador de números aleatórios, retornando a designação de cada ponto $x_l$, bem como o custo da função objetivo e tempo gasto pelo algoritmo até a convergência.
#
# Note que um dos resultados da função será um vetor coluna, em que o primeiro elemento contém o índice do cluster ao qual o primeiro ponto ($x_1$) foi designado, o segundo elemento contém o índice do cluster ao o segundo ponto ($x_2$) foi designado e assim sucessivamente.

# %% [markdown]
# ## Etapa 2
#
# Execute seu algoritmo para classificar as amostras do conjunto Iris. Realize 10 experimentos com o seu algoritmo, sendo que a cada experimento uma semente diferente deve ser usada no gerador de números aleatórios usado na sua versão do $k$-means.
#
# Ao final, construa uma tabela usando o módulo *tabulate* do Python, que mostra o identificador do experimento, quanto tempo o experimento levou até a convergência e qual foi o custo da função objetivo observada. Calcule também a média e desvio padrão dos cutos da função objetivo.
# ```
# https://scikit-learn.org/stable/auto_examples/datasets/plot_iris_dataset.html
# ```

# %% [markdown]
# ## Etapa 3
# Considerando a solução de melhor custo, calcule o Índice de Rand Ajustado (ARI) desta solução para verificar o quão boa foi a classificação gerada por seu algoritmo. Use o SciKit para isso:
#
# ```
# sklearn.metrics.adjusted_rand_score para
# ````

# %% [markdown]
# ## Etapa 4
#
# Usando o código disponível em https://scikit-learn.org/stable/auto_examples/cluster/plot_cluster_iris.html mostre graficamente a classificação das amostras obtida na melhor solução de melhor custo.

# %% [markdown]
# ## Etapa 5 (opcional)
#
# Caso esteja curioso, verifique se é praticável usar o solver counne (otimização global) ou bonmin, a partir do AMPL para resolver o MSSC.

# %%
# !pip install -q amplpy
from amplpy import AMPL, ampl_notebook
ampl = ampl_notebook(
modules=["highs", "cbc", "gurobi", "cplex", "coin"], # pick from over 20 modules including most commercial and open-source solvers
license_uuid="46db2306-167b-42bd-87da-27f82915b24d") # your course UUID
# Out:
# Licensed to Bundle #6572.7002 expiring 20240731: ECT2524 Introduction to Optimization, Prof. Everton Santi, Federal University of Rio Grande do Norte.
